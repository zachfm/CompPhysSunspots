# %%
from numpy import genfromtxt
import matplotlib.pyplot as mpl
import numpy as np
import scipy.optimize as opt
import math

data_file = 'daily.csv'

data = genfromtxt(data_file, delimiter=';')

year = data[:,3]
spots = data[:,4]

bad_data = np.argwhere(spots==-1)
print(len(spots))
print(len(bad_data))

spots = np.delete(spots, bad_data)
year = np.delete(year, bad_data)
N = len(spots)
# Out:
# 72743
# 3247

# %%
print(data)
# Out:
# [[  1.81800000e+03   1.00000000e+00   1.00000000e+00 ...,  -1.00000000e+00
#     0.00000000e+00   1.00000000e+00]
#  [  1.81800000e+03   1.00000000e+00   2.00000000e+00 ...,  -1.00000000e+00
#     0.00000000e+00   1.00000000e+00]
#  [  1.81800000e+03   1.00000000e+00   3.00000000e+00 ...,  -1.00000000e+00
#     0.00000000e+00   1.00000000e+00]
#  ...,
#  [  2.01700000e+03   2.00000000e+00   2.60000000e+01 ...,   2.80000000e+00
#     1.10000000e+01   0.00000000e+00]
#  [  2.01700000e+03   2.00000000e+00   2.70000000e+01 ...,   3.00000000e+00
#     1.90000000e+01   0.00000000e+00]
#  [  2.01700000e+03   2.00000000e+00   2.80000000e+01 ...,   5.00000000e+00
#     1.40000000e+01   0.00000000e+00]]

# %%
mpl.figure(figsize=(20,3))
mpl.clf()
mpl.plot(year,spots)
mpl.show()

#compute mean
mean = 0
for x in spots:
    mean+=x
mean/=N

#remove constant offset
for i in range(N):
    spots[i]-=mean

#plot modified function
mpl.figure(figsize=(20,3))
mpl.clf()
mpl.plot(year,spots)
mpl.plot(year,-100*np.sin(.625*year))
mpl.show()

#compute mean square
meansq = 0
for x in spots:
    meansq+=x**2
meansq/=N

# %%
def schuster_sum(w,t,x,trigfunc):
    #assert t and x are equal length
    if len(t) != len(x):
        print("t and x must be equal length")
    c = 0
    for k in range(0,len(t)):
        c += x[k]*trigfunc(w*t[k])
    return c

def schuster(w,t,x):
    sin_sum = schuster_sum(w, t,x, math.sin)
    cos_sum = schuster_sum(w, t,x, math.cos)
    return (sin_sum**2 + cos_sum**2)/len(t)**2

#compute the schuster over a range of angular frequencies
sch = []
freq = np.linspace(.4,.8,200)
for i in range(0,len(freq)):
    sch.append(schuster(freq[i],year,spots))

#plot schuster as a function of angular frequency
mpl.figure(figsize=(20,3))
mpl.clf()
mpl.plot(freq,sch)
mpl.show()

# %%
#plot schuster as a function of angular frequency
mpl.figure(figsize=(20,3))
mpl.clf()
mpl.plot(freq,sch)
mpl.show()

def f(w):
    return -1*schuster(w,year,spots)


bound = [.56, .58, .6]
maximum = opt.minimize_scalar(f,bounds).x

mpl.figure(figsize=(20,3))
mpl.clf()
mpl.plot(freq,sch)
mpl.plot([bound[0],bound[0]],[0,schuster(bound[0],year,spots)])
mpl.plot([bound[2],bound[2]],[0,schuster(bound[2],year,spots)])
mpl.scatter(maximum,schuster(maximum,year,spots))
mpl.show()

# %%
# (1-2*schuster(w)/(N*mean**2) )**(1-.5*N)

def prob(w):
    base = 1-2*schuster(w,year,spots)/(N*meansq)
    exp = 1-.5*N
    return base**exp

#compute the schuster over a range of angular frequencies
p = []
freq = np.linspace(0,10,200)
for i in range(0,len(freq)):
    p.append(prob(freq[i]))

# %%
mpl.clf()
mpl.plot(freq,p)
mpl.show()

# %%
print(math.sqrt(meansq))
# Out:
# 77.28654793079366
